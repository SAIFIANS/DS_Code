# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1 = {"age":[30,40,50],"salary":[25000,40000,50000]}

# %%
d1
# Out:
# {'age': [30, 40, 50], 'salary': [25000, 40000, 50000]}

# %%
df1 = pd.DataFrame(d1)

# %%
df1
# Out:
#    age  salary
# 0   30   25000
# 1   40   40000
# 2   50   50000

# %%
df = pd.read_csv("Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#give information of top rows

df.head(10)
# Out:
#         rank discipline  phd  service gender  salary
# 0       Prof          B   56       49   Male  186960
# 1       Prof          A   12        6   Male   93000
# 2       Prof          A   23       20   Male  110515
# 3       Prof          A   40       31   Male  131205
# 4       Prof          B   20       18   Male  104800
# 5       Prof          A   20       20   Male  122400
# 6  AssocProf          A   20       17   Male   81285
# 7       Prof          A   18       18   Male  126300
# 8       Prof          A   29       19   Male   94350
# 9       Prof          A   51       51   Male   57800

# %%
#give information of bottom rows
df.tail(2)
# Out:
#     rank discipline  phd  service  gender  salary
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
#get column names

col = df.columns

# %%
col
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'gender', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
#information about the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   gender      78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# Accessing of columns

# %%
df["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df[["rank","phd","salary"]]
# Out:
#          rank  phd  salary
# 0        Prof   56  186960
# 1        Prof   12   93000
# 2        Prof   23  110515
# 3        Prof   40  131205
# 4        Prof   20  104800
# ..        ...  ...     ...
# 73       Prof   18  105450
# 74  AssocProf   19  104542
# 75       Prof   17  124312
# 76       Prof   28  109954
# 77       Prof   23  109646
#
# [78 rows x 3 columns]

# %%
df[df["gender"]=="Female"]
# Out:
#          rank discipline  phd  service  gender  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
#get all records of the dataframe where salary is higher than 100000

df[df["salary"]>100000]
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 7        Prof          A   18       18    Male  126300
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# ...

# %%
df[["rank","discipline"]][df["salary"]>100000]
# Out:
#          rank discipline
# 0        Prof          B
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# 5        Prof          A
# 7        Prof          A
# 10       Prof          B
# 11       Prof          B
# 13       Prof          B
# 14       Prof          B
# 15       Prof          B
# 18       Prof          A
# 19       Prof          A
# 21       Prof          A
# 26       Prof          A
# 27       Prof          A
# 29       Prof          B
# 30  AssocProf          B
# 31       Prof          B
# 32       Prof          A
# 33       Prof          B
# 34  AssocProf          B
# 35       Prof          B
# 36       Prof          B
# 37       Prof          A
# 39       Prof          B
# 40       Prof          A
# 44       Prof          B
# 45       Prof          B
# 47  AssocProf          B
# 48       Prof          B
# 49       Prof          B
# 51       Prof          B
# 52       Prof          A
# 58       Prof          B
# 59  AssocProf          B
# ...

# %%
#rank and salary where the gender is female

df[["rank","salary"]][df["gender"]=="Female"]
# Out:
#          rank  salary
# 39       Prof  129000
# 40       Prof  137000
# 41  AssocProf   74830
# 42   AsstProf   80225
# 43   AsstProf   77000
# 44       Prof  151768
# 45       Prof  140096
# 46   AsstProf   74692
# 47  AssocProf  103613
# 48       Prof  111512
# 49       Prof  122960
# 50   AsstProf   97032
# 51       Prof  127512
# 52       Prof  105000
# 53   AsstProf   73500
# 54  AssocProf   62884
# 55   AsstProf   72500
# 56  AssocProf   77500
# 57   AsstProf   72500
# 58       Prof  144651
# 59  AssocProf  103994
# 60   AsstProf   92000
# 61  AssocProf  103750
# 62  AssocProf  109650
# 63       Prof   91000
# 64  AssocProf   73300
# 65       Prof  117555
# 66   AsstProf   63100
# 67       Prof   90450
# 68   AsstProf   77500
# 69       Prof  116450
# 70   AsstProf   78500
# 71  AssocProf   71065
# 72       Prof  161101
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646

# %%
#access phd,rank, salary where rank is prof and gender is male

df[["phd","rank","salary"]][(df["rank"]=="Prof") & (df["gender"]=="Male")]
# Out:
#     phd  rank  salary
# 0    56  Prof  186960
# 1    12  Prof   93000
# 2    23  Prof  110515
# 3    40  Prof  131205
# 4    20  Prof  104800
# 5    20  Prof  122400
# 7    18  Prof  126300
# 8    29  Prof   94350
# 9    51  Prof   57800
# 10   39  Prof  128250
# 11   23  Prof  134778
# 13   35  Prof  162200
# 14   25  Prof  153750
# 15   17  Prof  150480
# 18   19  Prof  107300
# 19   29  Prof  150500
# 21   33  Prof  103106
# 24   30  Prof   91100
# 25   35  Prof   99418
# 26   38  Prof  148750
# 27   45  Prof  155865
# 29   21  Prof  123683
# 31   22  Prof  155750
# 32   27  Prof  103275
# 33   18  Prof  120000
# 35   28  Prof  126933
# 36   45  Prof  146856
# 37   20  Prof  102000

# %% [markdown]
# Minimum value, maximum, mean,median, variance and standard dev

# %%
df["salary"].min()
# Out:
# 57800

# %%
df["salary"].max()
# Out:
# 186960

# %%
df["salary"].mean()
# Out:
# 108023.78205128205

# %%
round(df["salary"].mean(),2)
# Out:
# 108023.78

# %%
x =23.564739947

# %%
round(x,3)
# Out:
# 23.565

# %%
df["salary"].median()
# Out:
# 104671.0

# %%
df["rank"].mode()
# Out:
# 0    Prof
# Name: rank, dtype: object

# %%
df["salary"].var()
# Out:
# 800531254.0427907

# %%
df["salary"].std()
# Out:
# 28293.66102226417

# %%
#unique values in a column

df["rank"].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
#number of unique values in a column

df["rank"].nunique()
# Out:
# 3

# %%
#unique value occurrences

df["rank"].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df["discipline"].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# Male      39
# Female    39
# Name: gender, dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#statistical summary of the dataframe

df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#index based slicing

df.iloc[10:51,2:5]
# Out:
#     phd  service  gender
# 10   39       33    Male
# 11   23       23    Male
# 12    1        0    Male
# 13   35       33    Male
# 14   25       19    Male
# 15   17        3    Male
# 16    8        3    Male
# 17    4        0    Male
# 18   19        7    Male
# 19   29       27    Male
# 20    4        4    Male
# 21   33       30    Male
# 22    4        2    Male
# 23    2        0    Male
# 24   30       23    Male
# 25   35       31    Male
# 26   38       19    Male
# 27   45       43    Male
# 28    7        2    Male
# 29   21       20    Male
# 30    9        7    Male
# 31   22       21    Male
# 32   27       19    Male
# 33   18       18    Male
# 34   12        8    Male
# 35   28       23    Male
# 36   45       45    Male
# 37   20        8    Male
# 38    4        3    Male
# 39   18       18  Female
# 40   39       36  Female
# 41   13        8  Female
# 42    4        2  Female
# 43    5        0  Female
# 44   23       19  Female
# 45   25       25  Female
# ...

# %%
#location based slicing

df.loc[10:50,["phd","salary"]]
# Out:
#     phd  salary
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032

# %%
#len : length

len(df)
# Out:
# 78

# %%
len(df.loc[10:50,["phd","salary"]])
# Out:
# 41

# %%
#create a copy of df and store in df1

df1 = df.copy()

# %%
df1
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#drop function

#column wise drop, axis=1

df1.drop("rank",axis=1)
# Out:
#    discipline  phd  service  gender  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# ..        ...  ...      ...     ...     ...
# 73          B   18       10  Female  105450
# 74          B   19        6  Female  104542
# 75          B   17       17  Female  124312
# 76          A   28       14  Female  109954
# 77          A   23       15  Female  109646
#
# [78 rows x 5 columns]

# %%
df1
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df1.drop("rank",axis=1,inplace=True)

# %%
#df1["rank"]

# %%
df1 = df1.drop(["phd","gender"],axis=1)

# %%
df1
# Out:
#    discipline  service  salary
# 0           B       49  186960
# 1           A        6   93000
# 2           A       20  110515
# 3           A       31  131205
# 4           B       18  104800
# ..        ...      ...     ...
# 73          B       10  105450
# 74          B        6  104542
# 75          B       17  124312
# 76          A       14  109954
# 77          A       15  109646
#
# [78 rows x 3 columns]

# %%
#row wise deletion, axis=0

df.drop(index=4,axis=0,inplace=True)

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [77 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        77 non-null     object
#  1   discipline  77 non-null     object
#  2   phd         77 non-null     int64
#  3   service     77 non-null     int64
#  4   gender      77 non-null     object
#  5   salary      77 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 4.2+ KB

# %%
#isna(): checks for missing values

df.isna()
# Out:
#      rank  discipline    phd  service  gender  salary
# 0   False       False  False    False   False   False
# 1   False       False  False    False   False   False
# 2   False       False  False    False   False   False
# 3   False       False  False    False   False   False
# 5   False       False  False    False   False   False
# ..    ...         ...    ...      ...     ...     ...
# 73  False       False  False    False   False   False
# 74  False       False  False    False   False   False
# 75  False       False  False    False   False   False
# 76  False       False  False    False   False   False
# 77  False       False  False    False   False   False
#
# [77 rows x 6 columns]

# %%
#column wise count of missing values

df.isna().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# gender        0
# salary        0
# dtype: int64

# %%
#drop records/rows having missing values

df.dropna(inplace=True)

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [77 rows x 6 columns]

# %%
#drop duplicates

df.drop_duplicates(inplace=True)

# %%
dt = pd.read_csv("titanic.csv")

# %%
dt
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
dt.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [77 rows x 6 columns]

# %%
#sort

df.sort_values("phd",ascending=False)
# Out:
#         rank discipline  phd  service  gender  salary
# 0       Prof          B   56       49    Male  186960
# 9       Prof          A   51       51    Male   57800
# 36      Prof          B   45       45    Male  146856
# 27      Prof          A   45       43    Male  155865
# 3       Prof          A   40       31    Male  131205
# ..       ...        ...  ...      ...     ...     ...
# 57  AsstProf          A    3        1  Female   72500
# 60  AsstProf          B    3        3  Female   92000
# 23  AsstProf          A    2        0    Male   85000
# 55  AsstProf          A    2        0  Female   72500
# 12  AsstProf          B    1        0    Male   88000
#
# [77 rows x 6 columns]

# %%
df["phd"].sort_values()
# Out:
# 12     1
# 23     2
# 55     2
# 60     3
# 57     3
#       ..
# 3     40
# 27    45
# 36    45
# 9     51
# 0     56
# Name: phd, Length: 77, dtype: int64

# %%
# grouping based on specific categories

df.groupby("rank")["salary"].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         124043.133333
# Name: salary, dtype: float64

# %%
df.groupby("rank").mean()
# Out:
# <ipython-input-285-bcdc0c8de0e5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("rank").mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.222222  21.488889  124043.133333

# %%
df.groupby(["rank",'gender'])["salary"].mean()
# Out:
# rank       gender
# AssocProf  Female     88512.800000
#            Male      102697.666667
# AsstProf   Female     78049.909091
#            Male       85918.000000
# Prof       Female    121967.611111
#            Male      125426.814815
# Name: salary, dtype: float64

# %%
df3 = df.groupby(["rank",'gender'])["salary"].mean()

# %%
df3
# Out:
# rank       gender
# AssocProf  Female     88512.800000
#            Male      102697.666667
# AsstProf   Female     78049.909091
#            Male       85918.000000
# Prof       Female    121967.611111
#            Male      125426.814815
# Name: salary, dtype: float64

# %%
df3 = df3.reset_index()

# %%
df3
# Out:
#         rank  gender         salary
# 0  AssocProf  Female   88512.800000
# 1  AssocProf    Male  102697.666667
# 2   AsstProf  Female   78049.909091
# 3   AsstProf    Male   85918.000000
# 4       Prof  Female  121967.611111
# 5       Prof    Male  125426.814815

# %%
df.groupby(["rank",'gender'])["salary"].min()
# Out:
# rank       gender
# AssocProf  Female    62884
#            Male      81285
# AsstProf   Female    63100
#            Male      73000
# Prof       Female    90450
#            Male      57800
# Name: salary, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["salary"])
plt.xlabel("Boxplot of salary")
plt.ylabel("salaries")
plt.title("Boxplot Example")
plt.show()

# %%
plt.scatter(df["phd"],df["salary"])
plt.xlabel("phd")
plt.ylabel("salary")
plt.show()

# %%
plt.hist(df["salary"])
# Out:
# (array([ 3., 15., 12., 13.,  9., 11.,  4.,  8.,  1.,  1.]),
#  array([ 57800.,  70716.,  83632.,  96548., 109464., 122380., 135296.,
#         148212., 161128., 174044., 186960.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(df["salary"],kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.distplot(df["salary"])
# Out:
# <ipython-input-298-4c41f212cbcf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["salary"])
# <Axes: xlabel='salary', ylabel='Density'>

# %%
sns.countplot(x="gender",data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df["gender"].value_counts()
# Out:
# Female    39
# Male      38
# Name: gender, dtype: int64

# %%
sns.scatterplot(x="phd",y="salary",data=df)
# Out:
# <Axes: xlabel='phd', ylabel='salary'>

# %%
sns.scatterplot(x="phd",y="salary",hue="discipline",data=df)
# Out:
# <Axes: xlabel='phd', ylabel='salary'>

# %%
sns.scatterplot(x="phd",y="salary",hue="gender",data=df)
# Out:
# <Axes: xlabel='phd', ylabel='salary'>

# %%
sns.scatterplot(x="phd",y="salary",hue="rank",data=df)
# Out:
# <Axes: xlabel='phd', ylabel='salary'>
